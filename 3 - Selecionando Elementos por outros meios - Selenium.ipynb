# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)
navegador.maximize_window()

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\Pagina Hashtag.html"
navegador.get(arquivo)
# Link -> file:///C:/Users/david/Documents/CursoDePython/Pagina%20Hashtag.html

# %% [markdown]
# #### Selecionando pela tag

# %%
# Selecionando o título
Titulo = navegador.find_element(By.TAG_NAME, "h2").text
print(Titulo)
# Out:
# TODOS OS CURSOS DA HASHTAG TREINAMENTOS

# %% [markdown]
# #### Selecionar pelo Partial Link Text (ou LINK_TEXT)

# %%
Curso = navegador.find_element(By.PARTIAL_LINK_TEXT, "PYTHON").text
print(Curso)
# Out:
# CURSO DE PYTHON ONLINE

# %% [markdown]
# #### Selecionar pelo class

# %%
navegador.find_element(By.CLASS_NAME, "custom-logo").click()
