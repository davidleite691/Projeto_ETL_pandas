# %% [markdown]
# # Matplotlib e Pandas
#
# O Pandas é uma biblioteca que permite a manipulação de dados de forma simples e eficiente. Ela é construída sobre o NumPy e permite a manipulação de dados de forma simples e eficiente. Quanto a gráficos, o Pandas utiliza o Matplotlib como base para a geração de gráficos.

# %% [markdown]
# ## Base de dados utilizada
#
# Para este notebook, será utilizado a base de dados do top 10 IBOV de maio a agosto de 2023. A base de dados foi obtida no site do Yahoo Finance. O IBOV é o índice da Bovespa, que é a bolsa de valores brasileira. O IBOV é composto pelas ações mais negociadas na bolsa de valores brasileira. Para compor o IBOV, é feito um cálculo de ponderação das ações, onde as ações mais negociadas possuem maior peso no índice. O IBOV é um índice que é utilizado para medir o desempenho médio das cotações das ações mais negociadas na bolsa de valores brasileira.

# %%
import pandas as pd

ARQUIVO_TOP_10_IBOV = 'top_10_ibov_mai_ago_2023.csv'

df_top_10_ibov = pd.read_csv(ARQUIVO_TOP_10_IBOV)
df_top_10_ibov['Date'] = pd.to_datetime(df_top_10_ibov['Date'], format='%Y-%m-%d')
df_top_10_ibov = df_top_10_ibov.set_index('Date', drop=True)
bancos = ['BBDC4', 'ITUB4', 'BBAS3']
df_top_10_ibov.head()
# Out:
#                 VALE3      ELET3      BBAS3      B3SA3  ABEV3      ITUB4  \
# Date
# 2023-01-02  87.478874  40.327332  31.615412  12.039818  14.19  23.893169
# 2023-01-03  87.322311  39.572250  31.026070  11.636853  14.17  23.395597
# 2023-01-04  87.478874  40.635326  31.425303  11.725308  14.25  23.463890
# 2023-01-05  88.946640  40.714806  32.860638  12.088961  14.29  24.195612
# 2023-01-06  90.355698  40.734676  33.316906  12.373984  14.32  24.615131
#
#                 BBDC4      WEGE3      PETR3      RENT3
# Date
# 2023-01-02  13.879215  37.771538  22.264847  50.636215
# 2023-01-03  13.190460  36.829731  21.950058  49.391312
# 2023-01-04  13.228148  37.077576  22.315893  49.974247
# 2023-01-05  13.802876  37.156883  23.039053  50.389210
# 2023-01-06  14.189168  37.702141  22.894421  51.347595

# %% [markdown]
# Podemos verificar que existe uma correlação positiva entre os pares de ações de bancos. Isso significa que quando uma ação sobe, a outra também sobe. Quando uma ação cai, a outra também cai. Isso é um indicativo de que existe uma correlação entre as ações de bancos. A correlação é uma medida estatística que indica a relação entre duas variáveis. A correlação pode ser positiva, negativa ou neutra. Quando a correlação é positiva, significa que as variáveis possuem uma relação direta. Quando uma variável aumenta, a outra também aumenta. Quando a correlação é negativa, significa que as variáveis possuem uma relação inversa. Quando uma variável aumenta, a outra diminui. Quando a correlação é neutra, significa que as variáveis não possuem relação entre si.
#
# Os valores da correlação variam entre -1 e 1. Quando a correlação é -1, significa que as variáveis possuem uma correlação negativa perfeita. Quando a correlação é 1, significa que as variáveis possuem uma correlação positiva perfeita. Quando a correlação é 0, significa que as variáveis não possuem correlação. Quanto mais próximo de 1 ou -1, mais forte é a correlação. Quanto mais próximo de 0, mais fraca é a correlação.
#
# O método `corr()` do Pandas calcula a correlação entre as variáveis de um DataFrame.

# %%
df_top_10_ibov.corr()
# Out:
#           VALE3     ELET3     BBAS3     B3SA3     ABEV3     ITUB4     BBDC4  \
# VALE3  1.000000  0.254017 -0.801388 -0.472413 -0.733513 -0.616604 -0.630104
# ELET3  0.254017  1.000000  0.072803  0.641147  0.089652  0.421773  0.476954
# BBAS3 -0.801388  0.072803  1.000000  0.665027  0.666072  0.858388  0.753427
# B3SA3 -0.472413  0.641147  0.665027  1.000000  0.576847  0.806739  0.932840
# ABEV3 -0.733513  0.089652  0.666072  0.576847  1.000000  0.573089  0.670614
# ITUB4 -0.616604  0.421773  0.858388  0.806739  0.573089  1.000000  0.883379
# BBDC4 -0.630104  0.476954  0.753427  0.932840  0.670614  0.883379  1.000000
# WEGE3 -0.114228 -0.748048 -0.213368 -0.575233 -0.033395 -0.450325 -0.443264
# PETR3 -0.649903  0.350004  0.924637  0.805945  0.614360  0.917005  0.856235
# RENT3 -0.699430  0.331517  0.895541  0.864826  0.582085  0.892079  0.888734
#
#           WEGE3     PETR3     RENT3
# VALE3 -0.114228 -0.649903 -0.699430
# ELET3 -0.748048  0.350004  0.331517
# BBAS3 -0.213368  0.924637  0.895541
# B3SA3 -0.575233  0.805945  0.864826
# ABEV3 -0.033395  0.614360  0.582085
# ITUB4 -0.450325  0.917005  0.892079
# BBDC4 -0.443264  0.856235  0.888734
# WEGE3  1.000000 -0.479820 -0.377449
# PETR3 -0.479820  1.000000  0.912472
# RENT3 -0.377449  0.912472  1.000000

# %% [markdown]
# Podemos aplicar um estilo de gradiente de cores para facilitar a visualização da correlação. No Pandas, há o método `style.background_gradient()`, que aplica um estilo de gradiente de cores no DataFrame. O parâmetro `cmap` recebe o nome do estilo de gradiente de cores. Neste caso, utilizaremos o estilo `coolwarm_r`, que é um estilo de gradiente de cores que vai do vermelho ao azul. O sufixo `_r` indica que o gradiente de cores será aplicado de forma reversa, ou seja, o gradiente original é de azul ao vermelho.
#
# Os mapas de cores são os disponíveis no Matplotlib. Para mais informações, acesse a [documentação](https://matplotlib.org/stable/tutorials/colors/colormaps.html).

# %%
# Exibição da correlação entre as ações a partir de um sistema de cores. Em que quando mais vermelho mais negativo
# e quanto mais azul mais azul mais positivo
df_top_10_ibov.corr().style.format(precision=2).background_gradient(cmap='coolwarm_r', vmin = -1, vmax = 1)
# -> importante colocar o vmin e o vmax, pois o interpretador não vai considerar o zero como ponto de mudança
# entre tons de azul e tons de vermelho
# Out:
# <style type="text/css">
# #T_734b3_row0_col0, #T_734b3_row1_col1, #T_734b3_row2_col2, #T_734b3_row3_col3, #T_734b3_row4_col4, #T_734b3_row5_col5, #T_734b3_row6_col6, #T_734b3_row7_col7, #T_734b3_row8_col8, #T_734b3_row9_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_734b3_row0_col1, #T_734b3_row1_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_734b3_row0_col2, #T_734b3_row2_col0 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_734b3_row0_col3, #T_734b3_row3_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_734b3_row0_col4, #T_734b3_row4_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_734b3_row0_col5, #T_734b3_row5_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_734b3_row0_col6, #T_734b3_row6_col0 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_734b3_row0_col7, #T_734b3_row7_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_734b3_row0_col8, #T_734b3_row8_col0 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_734b3_row0_col9, #T_734b3_row9_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_734b3_row1_col2, #T_734b3_row2_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_734b3_row1_col3, #T_734b3_row3_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_734b3_row1_col4, #T_734b3_row4_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_734b3_row1_col5, #T_734b3_row5_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_734b3_row1_col6, #T_734b3_row6_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_734b3_row1_col7, #T_734b3_row7_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_734b3_row1_col8, #T_734b3_row8_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_734b3_row1_col9, #T_734b3_row9_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_734b3_row2_col3, #T_734b3_row2_col4, #T_734b3_row3_col2, #T_734b3_row4_col2, #T_734b3_row4_col6, #T_734b3_row6_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_734b3_row2_col5, #T_734b3_row5_col2, #T_734b3_row6_col8, #T_734b3_row8_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_734b3_row2_col6, #T_734b3_row6_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_734b3_row2_col7, #T_734b3_row7_col2 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_734b3_row2_col8, #T_734b3_row8_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_734b3_row2_col9, #T_734b3_row5_col9, #T_734b3_row9_col2, #T_734b3_row9_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_734b3_row3_col4, #T_734b3_row4_col3, #T_734b3_row4_col5, #T_734b3_row5_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_734b3_row3_col5, #T_734b3_row3_col8, #T_734b3_row5_col3, #T_734b3_row8_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_734b3_row3_col6, #T_734b3_row6_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_734b3_row3_col7, #T_734b3_row7_col3 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_734b3_row3_col9, #T_734b3_row9_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_734b3_row4_col7, #T_734b3_row7_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_734b3_row4_col8, #T_734b3_row8_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_734b3_row4_col9, #T_734b3_row9_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_734b3_row5_col6, #T_734b3_row6_col5, #T_734b3_row6_col9, #T_734b3_row9_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_734b3_row5_col7, #T_734b3_row7_col5 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_734b3_row5_col8, #T_734b3_row8_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_734b3_row6_col7, #T_734b3_row7_col6 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_734b3_row7_col8, #T_734b3_row8_col7 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_734b3_row7_col9, #T_734b3_row9_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_734b3_row8_col9, #T_734b3_row9_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_734b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_734b3_level0_col0" class="col_heading level0 col0" >VALE3</th>
#       <th id="T_734b3_level0_col1" class="col_heading level0 col1" >ELET3</th>
#       <th id="T_734b3_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#       <th id="T_734b3_level0_col3" class="col_heading level0 col3" >B3SA3</th>
#       <th id="T_734b3_level0_col4" class="col_heading level0 col4" >ABEV3</th>
#       <th id="T_734b3_level0_col5" class="col_heading level0 col5" >ITUB4</th>
#       <th id="T_734b3_level0_col6" class="col_heading level0 col6" >BBDC4</th>
#       <th id="T_734b3_level0_col7" class="col_heading level0 col7" >WEGE3</th>
#       <th id="T_734b3_level0_col8" class="col_heading level0 col8" >PETR3</th>
#       <th id="T_734b3_level0_col9" class="col_heading level0 col9" >RENT3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_734b3_level0_row0" class="row_heading level0 row0" >VALE3</th>
#       <td id="T_734b3_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_734b3_row0_col1" class="data row0 col1" >0.25</td>
#       <td id="T_734b3_row0_col2" class="data row0 col2" >-0.80</td>
#       <td id="T_734b3_row0_col3" class="data row0 col3" >-0.47</td>
#       <td id="T_734b3_row0_col4" class="data row0 col4" >-0.73</td>
#       <td id="T_734b3_row0_col5" class="data row0 col5" >-0.62</td>
#       <td id="T_734b3_row0_col6" class="data row0 col6" >-0.63</td>
#       <td id="T_734b3_row0_col7" class="data row0 col7" >-0.11</td>
#       <td id="T_734b3_row0_col8" class="data row0 col8" >-0.65</td>
#       <td id="T_734b3_row0_col9" class="data row0 col9" >-0.70</td>
#     </tr>
#     <tr>
#       <th id="T_734b3_level0_row1" class="row_heading level0 row1" >ELET3</th>
#       <td id="T_734b3_row1_col0" class="data row1 col0" >0.25</td>
#       <td id="T_734b3_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_734b3_row1_col2" class="data row1 col2" >0.07</td>
#       <td id="T_734b3_row1_col3" class="data row1 col3" >0.64</td>
#       <td id="T_734b3_row1_col4" class="data row1 col4" >0.09</td>
#       <td id="T_734b3_row1_col5" class="data row1 col5" >0.42</td>
#       <td id="T_734b3_row1_col6" class="data row1 col6" >0.48</td>
#       <td id="T_734b3_row1_col7" class="data row1 col7" >-0.75</td>
#       <td id="T_734b3_row1_col8" class="data row1 col8" >0.35</td>
#       <td id="T_734b3_row1_col9" class="data row1 col9" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_734b3_level0_row2" class="row_heading level0 row2" >BBAS3</th>
#       <td id="T_734b3_row2_col0" class="data row2 col0" >-0.80</td>
#       <td id="T_734b3_row2_col1" class="data row2 col1" >0.07</td>
#       <td id="T_734b3_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_734b3_row2_col3" class="data row2 col3" >0.67</td>
#       <td id="T_734b3_row2_col4" class="data row2 col4" >0.67</td>
#       <td id="T_734b3_row2_col5" class="data row2 col5" >0.86</td>
#       <td id="T_734b3_row2_col6" class="data row2 col6" >0.75</td>
#       <td id="T_734b3_row2_col7" class="data row2 col7" >-0.21</td>
#       <td id="T_734b3_row2_col8" class="data row2 col8" >0.92</td>
#       <td id="T_734b3_row2_col9" class="data row2 col9" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_734b3_level0_row3" class="row_heading level0 row3" >B3SA3</th>
#       <td id="T_734b3_row3_col0" class="data row3 col0" >-0.47</td>
#       <td id="T_734b3_row3_col1" class="data row3 col1" >0.64</td>
#       <td id="T_734b3_row3_col2" class="data row3 col2" >0.67</td>
#       <td id="T_734b3_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_734b3_row3_col4" class="data row3 col4" >0.58</td>
#       <td id="T_734b3_row3_col5" class="data row3 col5" >0.81</td>
#       <td id="T_734b3_row3_col6" class="data row3 col6" >0.93</td>
#       <td id="T_734b3_row3_col7" class="data row3 col7" >-0.58</td>
#       <td id="T_734b3_row3_col8" class="data row3 col8" >0.81</td>
#       <td id="T_734b3_row3_col9" class="data row3 col9" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_73

# %%
# Analisando somente os bancos que foram postos no gráfico de variação diária
df_top_10_ibov[bancos].corr().style.format(precision=2).background_gradient(cmap="coolwarm_r", vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_74624_row0_col0, #T_74624_row1_col1, #T_74624_row2_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_74624_row0_col1, #T_74624_row1_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_74624_row0_col2, #T_74624_row2_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_74624_row1_col2, #T_74624_row2_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_74624">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74624_level0_col0" class="col_heading level0 col0" >BBDC4</th>
#       <th id="T_74624_level0_col1" class="col_heading level0 col1" >ITUB4</th>
#       <th id="T_74624_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74624_level0_row0" class="row_heading level0 row0" >BBDC4</th>
#       <td id="T_74624_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_74624_row0_col1" class="data row0 col1" >0.88</td>
#       <td id="T_74624_row0_col2" class="data row0 col2" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_74624_level0_row1" class="row_heading level0 row1" >ITUB4</th>
#       <td id="T_74624_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_74624_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_74624_row1_col2" class="data row1 col2" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_74624_level0_row2" class="row_heading level0 row2" >BBAS3</th>
#       <td id="T_74624_row2_col0" class="data row2 col0" >0.75</td>
#       <td id="T_74624_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_74624_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
#exibindo tudo menos as colunas dos bancos
df_top_10_ibov.drop(columns=bancos).corr().style.format(precision=2).background_gradient(cmap='coolwarm_r', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_8a5fa_row0_col0, #T_8a5fa_row1_col1, #T_8a5fa_row2_col2, #T_8a5fa_row3_col3, #T_8a5fa_row4_col4, #T_8a5fa_row5_col5, #T_8a5fa_row6_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8a5fa_row0_col1, #T_8a5fa_row1_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_8a5fa_row0_col2, #T_8a5fa_row2_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_8a5fa_row0_col3, #T_8a5fa_row3_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_8a5fa_row0_col4, #T_8a5fa_row4_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_8a5fa_row0_col5, #T_8a5fa_row5_col0 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_8a5fa_row0_col6, #T_8a5fa_row6_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_8a5fa_row1_col2, #T_8a5fa_row2_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_8a5fa_row1_col3, #T_8a5fa_row3_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_8a5fa_row1_col4, #T_8a5fa_row4_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_8a5fa_row1_col5, #T_8a5fa_row5_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_8a5fa_row1_col6, #T_8a5fa_row6_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_8a5fa_row2_col3, #T_8a5fa_row3_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_8a5fa_row2_col4, #T_8a5fa_row4_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_8a5fa_row2_col5, #T_8a5fa_row5_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_8a5fa_row2_col6, #T_8a5fa_row6_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_8a5fa_row3_col4, #T_8a5fa_row4_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_8a5fa_row3_col5, #T_8a5fa_row5_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_8a5fa_row3_col6, #T_8a5fa_row6_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_8a5fa_row4_col5, #T_8a5fa_row5_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_8a5fa_row4_col6, #T_8a5fa_row6_col4 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_8a5fa_row5_col6, #T_8a5fa_row6_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8a5fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a5fa_level0_col0" class="col_heading level0 col0" >VALE3</th>
#       <th id="T_8a5fa_level0_col1" class="col_heading level0 col1" >ELET3</th>
#       <th id="T_8a5fa_level0_col2" class="col_heading level0 col2" >B3SA3</th>
#       <th id="T_8a5fa_level0_col3" class="col_heading level0 col3" >ABEV3</th>
#       <th id="T_8a5fa_level0_col4" class="col_heading level0 col4" >WEGE3</th>
#       <th id="T_8a5fa_level0_col5" class="col_heading level0 col5" >PETR3</th>
#       <th id="T_8a5fa_level0_col6" class="col_heading level0 col6" >RENT3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a5fa_level0_row0" class="row_heading level0 row0" >VALE3</th>
#       <td id="T_8a5fa_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_8a5fa_row0_col1" class="data row0 col1" >0.25</td>
#       <td id="T_8a5fa_row0_col2" class="data row0 col2" >-0.47</td>
#       <td id="T_8a5fa_row0_col3" class="data row0 col3" >-0.73</td>
#       <td id="T_8a5fa_row0_col4" class="data row0 col4" >-0.11</td>
#       <td id="T_8a5fa_row0_col5" class="data row0 col5" >-0.65</td>
#       <td id="T_8a5fa_row0_col6" class="data row0 col6" >-0.70</td>
#     </tr>
#     <tr>
#       <th id="T_8a5fa_level0_row1" class="row_heading level0 row1" >ELET3</th>
#       <td id="T_8a5fa_row1_col0" class="data row1 col0" >0.25</td>
#       <td id="T_8a5fa_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_8a5fa_row1_col2" class="data row1 col2" >0.64</td>
#       <td id="T_8a5fa_row1_col3" class="data row1 col3" >0.09</td>
#       <td id="T_8a5fa_row1_col4" class="data row1 col4" >-0.75</td>
#       <td id="T_8a5fa_row1_col5" class="data row1 col5" >0.35</td>
#       <td id="T_8a5fa_row1_col6" class="data row1 col6" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_8a5fa_level0_row2" class="row_heading level0 row2" >B3SA3</th>
#       <td id="T_8a5fa_row2_col0" class="data row2 col0" >-0.47</td>
#       <td id="T_8a5fa_row2_col1" class="data row2 col1" >0.64</td>
#       <td id="T_8a5fa_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_8a5fa_row2_col3" class="data row2 col3" >0.58</td>
#       <td id="T_8a5fa_row2_col4" class="data row2 col4" >-0.58</td>
#       <td id="T_8a5fa_row2_col5" class="data row2 col5" >0.81</td>
#       <td id="T_8a5fa_row2_col6" class="data row2 col6" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_8a5fa_level0_row3" class="row_heading level0 row3" >ABEV3</th>
#       <td id="T_8a5fa_row3_col0" class="data row3 col0" >-0.73</td>
#       <td id="T_8a5fa_row3_col1" class="data row3 col1" >0.09</td>
#       <td id="T_8a5fa_row3_col2" class="data row3 col2" >0.58</td>
#       <td id="T_8a5fa_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_8a5fa_row3_col4" class="data row3 col4" >-0.03</td>
#       <td id="T_8a5fa_row3_col5" class="data row3 col5" >0.61</td>
#       <td id="T_8a5fa_row3_col6" class="data row3 col6" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_8a5fa_level0_row4" class="row_heading level0 row4" >WEGE3</th>
#       <td id="T_8a5fa_row4_col0" class="data row4 col0" >-0.11</td>
#       <td id="T_8a5fa_row4_col1" class="data row4 col1" >-0.75</td>
#       <td id="T_8a5fa_row4_col2" class="data row4 col2" >-0.58</td>
#       <td id="T_8a5fa_row4_col3" class="data row4 col3" >-0.03</td>
#       <td id="T_8a5fa_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_8a5fa_row4_col5" class="data row4 col5" >-0.48</td>
#       <td id="T_8a5fa_row4_col6" class="data row4 col6" >-0.38</td>
#     </tr>
#     <tr>
#       <th id="T_8a5fa_level0_row5" class="row_heading level0 row5" >PETR3</th>
#       <td id="T_8a5fa_row5_col0" class="data row5 col0" >-0.65</td>
#       <td id="T_8a5fa_row5_col1" class="data row5 col1" >0.35</td>
#       <td id="T_8a5fa_row5_col2" class="data row5 col2" >0.81</td>
#       <td id="T_8a5fa_row5_col3" class="data row5 col3" >0.61</td>
#       <td id="T_8a5fa_row5_col4" class="data row5 col4" >-0.48</td>
#       <td id="T_8a5fa_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_8a5fa_row5_col6" class="data row5 col6" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_8a5fa_level0_row6" class="row_heading level0 row6" >RENT3</th>
#       <td id="T_8a5fa_row6_col0" class="data row6 col0" >-0.70</td>
#       <td id="T_8a5fa_row6_col1" class="data row6 col1" >0.33</td>
#       <td id="T_8a5fa_row6_col2" class="data row6 col2" >0.86</td>
#       <td id="T_8a5fa_row6_col3" class="data row6 col3" >0.58</td>
#       <td id="T_8a5fa_row6_col4" class="data row6 col4" >-0.38</td>
#       <td id="T_8a5fa_row6_col5" class="data row6 col5" >0.91</td>
#       <td id="T_8a5fa_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>
