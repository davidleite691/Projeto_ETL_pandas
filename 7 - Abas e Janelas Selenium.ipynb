# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)
navegador.maximize_window()

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\Pagina Hashtag.html"
navegador.get(arquivo)

# %% [markdown]
# #### Botão que abre outra janela

# %%
navegador.find_element(By.XPATH, '/html/body/section[2]/div/div[4]/figure/a/img').click()

# %% [markdown]
# ### Outra aba ou janela

# %%
# identificação das páginas que estão sendo utilizadas
aba_original = navegador.window_handles[0]
aba_2 = navegador.window_handles[1]

# Trocar a página que o Selenium está vendo
navegador.switch_to.window(aba_2)

# Preenche o formulário
navegador.find_element(By.XPATH, '//*[@id="firstname"]').send_keys("David")
